# %% [markdown]
# ####  " __init__  is used to automatically initialize (set up) an object when it is created. "

# %%
# ----------- Without __init__ -----------

class BankAccount:
    def create_account(self, owner, balance):
        self.owner = owner
        self.balance = balance

    def deposit(self, amount):
        self.balance += amount

    def show_balance(self):
        print(self.owner, "Balance:", self.balance)


acc1 = BankAccount()
acc1.create_account("John", 1000)
acc1.deposit(500)
acc1.show_balance()
# Out:
# John Balance: 1500

# %%
# ----------- With __init__ -----------

class BankAccount:
    def __init__(self, owner, balance):
        self.owner = owner
        self.balance = balance

    def deposit(self, amount):
        self.balance += amount

    def show_balance(self):
        print(self.owner, "Balance:", self.balance)


acc2 = BankAccount("John", 1000)
acc2.deposit(500)
acc2.show_balance()


acc3 = BankAccount("Sharath",1919191)

acc3.show_balance()
# Out:
# John Balance: 1500
# Sharath Balance: 1919191

# %%
class BankInfo:
    def __init__(self,name,account_number,balance):
        self.name = name
        self.account_number = account_number
        self.balance = balance

    def display(self):
       print(self.name ,self.account_number,self.balance)

person1 = BankInfo("Shararth",78171516, 7671.11)
p2 = BankInfo("ravi",332934,8999.9)


person1.display()
p2.display()
# Out:
# Shararth 78171516 7671.11
# ravi 332934 8999.9

# %%
class BankInfo:
    
    def details(self,name,balance):
        self.name = name
        self.balance = balance
    def show(self):
        print(self.name, self.balance)

p1 = BankInfo()
p2 = BankInfo()

p1.details("sharath",9181)

p1.show()



p2.details("ravi", 16151)
p2.show()
# Out:
# sharath 9181
# ravi 16151
