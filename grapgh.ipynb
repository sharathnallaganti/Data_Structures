# %% [markdown]
# **A Graph is a non-linear data structure defined as an ordered pair**
#
#           𝐺 = (𝑉,𝐸)
#
# A set of vertices (nodes) and A set of edges that connect pairs of vertices
#
# Mathematically:
# Where:
#
# V = Set of vertices, E = Set of edges
#
# ![image.png](attachment:39b82746-f66c-43d0-8a05-dd9954c496c1.png)
#
#
# **Characteristics**
#
# 1. A graph may be directed or undirected.
# 2. A graph may be weighted or unweighted.
# 3. Graphs are used to model pairwise relationships between objects.
# 4. Graphs are non-linear structures (unlike arrays, stacks, queues).

# %% [markdown]
# # Properties of a Graph
#
# **Order** – The total number of vertices present in a graph.
# It is denoted by ∣V∣.
#
# **Size** – The total number of edges in a graph.
# It is denoted by ∣E∣.
#
# **Degree of a Vertex** – The number of edges incident (connected) to a vertex.
# In undirected graphs, each connection counts once.
#
# **In-degree** – The number of edges coming into a vertex.
# Defined only in directed graphs.
#
# **Out-degree** – The number of edges going out from a vertex.
# Also defined only in directed graphs.
#
# **Sum of Degrees Property** – In an undirected graph, the sum of all vertex degrees equals 2∣E∣.
# In directed graphs, total in-degree equals total out-degree equals ∣E∣.
#
# **Path** – A sequence of vertices connected by edges.
# It represents a route from one vertex to another.
#
# **Cycle** – A path that starts and ends at the same vertex.
# It forms a closed loop in the graph.
#
# **Connected Graph** – A graph where every vertex is reachable from every other vertex.
# There is at least one path between any two vertices.
#
# **Simple Graph** – A graph with no self-loops and no multiple edges between the same pair of vertices.
# Each pair of vertices has at most one edge.
#
# **Complete Graph** – A graph in which every pair of distinct vertices is connected by an edge.
# A complete graph with n vertices has n(n−1)/2 edges.
#
# **Subgraph** – A graph formed using a subset of vertices and edges of another graph.
# It must maintain the original connections between chosen vertices.

# %%
class Graph:
    def __init__(self):
        self.graph = {}

    def add_vertex(self, vertex):
        if vertex not in self.graph:
            self.graph[vertex] = []

    def add_edge(self, v1, v2):
        if v1 not in self.graph:
            self.add_vertex(v1)
        if v2 not in self.graph:
            self.add_vertex(v2)

        self.graph[v1].append(v2)
        self.graph[v2].append(v1)  # Remove this line for directed graph

    def display(self):
        for vertex in self.graph:
            print(vertex, "->", self.graph[vertex])
